# %% [markdown]
# 【台北大學碩士班課程】統計應用數學與計算<br>
# 【授課老師】汪群超<br>
# 【主要內容】主成分分析（PCA）在實際資料上的實作<br>
# 【內容要求】<br>

# %%
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
import seaborn as sns
import numpy as np
import pandas as pd

# %%
file = r'C:\Course\1112ShallowMachineLearning\hw\hw1PCA'

# %% [markdown]
# # 習題1
# 有一組資料來自義大利某個地區三個紅酒製造商所產的紅酒，資料內容包括的 178 支紅酒的 13 種化學成分。利用這組資料回答下列問題：

# %% [markdown]
# 讀取資料

# %%
df = pd.read_excel(file + r'\wine.xlsx')
print(df.shape)
df.head(5)
# Out:
# (178, 14)
#    Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0    14.23        1.71  2.43          15.6        127           2.80
# 1    13.20        1.78  2.14          11.2        100           2.65
# 2    13.16        2.36  2.67          18.6        101           2.80
# 3    14.37        1.95  2.50          16.8        113           3.85
# 4    13.24        2.59  2.87          21.0        118           2.80
#
#    Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    OD280  Proline  Customer_Segment
# 0   3.92     1065                 1
# 1   3.40     1050                 1
# 2   3.17     1185                 1
# 3   3.45     1480                 1
# 4   2.93      735                 1

# %% [markdown]
# ## 繪製變數間的相關係數圖
# 從下圖可明顯發現，變數之間有相關性，Total_Phenois與Flavanoids有強烈的正相關

# %%
corr =  df.iloc[:,:13].corr()

# Create a mask
mask = np.triu(np.ones_like(corr, dtype=bool))

# Create a custom divergin palette
plt.figure(figsize=(10,8))
sns.heatmap(df.iloc[:,:13].corr(), cmap='coolwarm', annot=True, fmt=".2f", mask=mask)
plt.show()

# %%
df.iloc[:,:13].boxplot()
# Out:
# <AxesSubplot: >
